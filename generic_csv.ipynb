# %% [markdown]
# # 0 - Packages

# %%
import numpy as np
import matplotlib.pyplot as plt
import lmfit

# %%
X = np.linspace(-10, 10, 20)
Y = np.linspace(-10, 10, 20)
XX, YY = np.meshgrid(X, Y)  # Create a grid
X = XX.flatten()
Y = YY.flatten()

def func_to_fit(x,y):
    return 1 - x**2 - y**2
ZZ = func_to_fit(XX,YY)  # Example Z data
Z = ZZ.flatten()

# Create a figure with two subplots (1 row, 2 columns)
fig = plt.figure(figsize=(10, 5))

# First subplot: 3D plot
ax1 = fig.add_subplot(111, projection='3d')
ax1.scatter(X,Y,Z)

# Show the plot
plt.tight_layout()  # Adjust layout so there's no overlap
plt.show()

# %%
model = lmfit.Model(freq_disp)
params = model.make_params(D0={'value': 5.0e12, 'vary': True, 'min':-np.inf, 'max':np.inf},
                           D1={'value': 170.0e9, 'vary': True, 'min':-np.inf, 'max':np.inf},
                           D2={'value': -50.0e6, 'vary': True, 'min':-np.inf, 'max':np.inf},
                           D3={'value': 1.0e7, 'vary': True, 'min':-np.inf, 'max':np.inf})
result = model.fit(Y_disp, params, u=X_disp, method='leastsq')

ans = result.params.valuesdict()

plt.plot(X, result.init_fit, c='green', linewidth=2, linestyle='dashed', label='initial fit')
plt.plot(X, result.best_fit, c='red', linewidth=2, linestyle='dashed', label='best fit')
plt.legend()
result.params
# Out:
# C:\Users\conde\AppData\Local\Temp\ipykernel_69772\1787370556.py:4: DeprecationWarning: numpy.core.numeric is deprecated and has been renamed to numpy._core.numeric. The numpy._core namespace contains private NumPy internals and its use is discouraged, as NumPy internals can change without warning in any release. In practice, most real-world usage of numpy.core is to access functionality in the public NumPy API. If that is the case, use the public NumPy API. If not, you are using NumPy internals. If you would still like to access an internal attribute, use numpy._core.numeric._frombuffer.
#   df_raw = pickle.load(f)
